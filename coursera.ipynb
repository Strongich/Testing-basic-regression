# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# from sklearn.linear_model import LinearRegression
# from sklearn.metrics import r2_score, mean_squared_error
# from sklearn.model_selection import train_test_split
import statsmodels.api
import statsmodels.formula.api as smf

# %%
df = pd.read_csv('US Police shootings in from 2015-22.csv', sep = ',')
df
# Out:
#         id                name        date   manner_of_death           armed  \
# 0        1          Tim Elliot  2015-01-02              shot             gun
# 1        2    Lewis Lee Lembke  2015-01-02              shot             gun
# 2        3  John Paul Quintero  2015-01-03  shot and Tasered         unarmed
# 3        4     Matthew Hoffman  2015-01-04              shot      toy weapon
# 4        5   Michael Rodriguez  2015-01-04              shot        nail gun
# ...    ...                 ...         ...               ...             ...
# 7677  7678                 NaN  2022-08-23              shot  unknown weapon
# 7678  7679                 NaN  2022-08-23              shot         machete
# 7679  7680       Geraldo Reyes  2022-08-23              shot             gun
# 7680  7681                 NaN  2022-08-23              shot             gun
# 7681  7682                 NaN  2022-08-23              shot    undetermined
#
# ...

# %%
# lets make table with only age and gender, where we will make Male = 1, Female = 0
df2 = df[['age','gender']].dropna()
# after clearing dataset, lets make index column comfortable 
df2.index = np.arange(1, len(df2) + 1) 
df2
# Out:
#        age gender
# 1     53.0      M
# 2     47.0      M
# 3     23.0      M
# 4     32.0      M
# 5     39.0      M
# ...    ...    ...
# 7200  37.0      M
# 7201  42.0      F
# 7202  41.0      F
# 7203  48.0      M
# 7204  32.0      M
#
# [7204 rows x 2 columns]

# %%
df2['gender'] = np.where((df2.gender == 'F'), 0, df2.gender )
df2['gender'] = np.where((df2.gender == 'M'), 1, df2.gender )
df2
# Out:
#        age gender
# 1     53.0      1
# 2     47.0      1
# 3     23.0      1
# 4     32.0      1
# 5     39.0      1
# ...    ...    ...
# 7200  37.0      1
# 7201  42.0      0
# 7202  41.0      0
# 7203  48.0      1
# 7204  32.0      1
#
# [7204 rows x 2 columns]

# %%
print ("OLS regression model for the association between age and gender")
regression = smf.ols('age ~ gender', data=df2).fit()
print(regression.summary())
# Out:
# OLS regression model for the association between age and gender
#                             OLS Regression Results
# ...
# Dep. Variable:                    age   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                    0.1003
# Date:                Tue, 27 Sep 2022   Prob (F-statistic):              0.752
# Time:                        18:08:49   Log-Likelihood:                -28670.
# No. Observations:                7204   AIC:                         5.734e+04
# Df Residuals:                    7202   BIC:                         5.736e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# ...
